# %%
# Instructions
# your answers should be in a new cell below the questions cell

# %%
# question 1
# The Misleading Variable: You run the following code. What
# will be the final value of result? Explain the steps R takes to get there.
x <- 10
y <- "5"
result <- x + y

# %%
it would result in an error because
R cannot add a number and a string together.

# %%
# question 2
# You have an object in your environment called patient_data. 
# You run the command rm(patient_data). 
# What happens when you then run View(patient_data)? What does this teach you about the rm() function?
# you can test with inbuild data

# %%
it would result in an error because
R cannot find the patient_data after using the rm() function.
this is because rm() function deletes it from the memory

# %%
# question 3
# head() vs. View(): 
# What is the key practical difference between using head(ebola_data) and View(ebola_data)? 
# When would you use one over the other?

# %%
when you use head(ebola_data), it displays the first six rows of the dataset in the console,
while View(ebola_data) opens the entire dataset in a separate tab for easier browsing.

# %%
# question 4
# The head() function allows you to swap the order of its arguments if you use their names. 
# Why does head(n = 3, x = women) work perfectly, but head(3, women) fails? 
# What fundamental R rule does this demonstrate?

# %%
this is because the other must be number of rows to display 
and then the data frame or object to display from.

# %%
# question 5
# In the lesson, the object ebola_sierra_leone_data was renamed to ebola_data. 
# Why is this a good programming practice, especially as your projects get larger?

# %%
So that the name is shorter and easier to type,
making the code more readable and manageable as the project grows in complexity.

# %%
# question 6
# You want to create a single sentence that says: "The first patient's ID was 167". 
# You have the ebola_data dataframe from the lesson. 
# Which of the following lines of code will successfully achieve this? Explain why the others fail.

# Option A
paste("The first patient's ID was", ebola_data[1, 1])

# Option B
paste("The first patient's ID was", head(ebola_data$id, 1))

# Option C
paste("The first patient's ID was", ebola_data$id[1])

# %%
ebola_data <- read.csv("https://tinyurl.com/ebola-data-sample")
View(ebola_data)
# Out:
#     id  age sex status    date_of_onset date_of_sample district
# 1   167 55  M   confirmed 2014-06-15    2014-06-21     Kenema
# 2   129 41  M   confirmed 2014-06-13    2014-06-18     Kailahun
# 3   270 12  F   confirmed 2014-06-28    2014-07-03     Kailahun
# 4   187 NA  F   confirmed 2014-06-19    2014-06-24     Kailahun
# 5    85 20  M   confirmed 2014-06-08    2014-06-24     Kailahun
# 6   277 30  F   confirmed 2014-06-29    2014-07-01     Kenema
# 7   263 62  F   confirmed 2014-06-28    2014-07-03     Kenema
# 8    79 45  M   confirmed 2014-06-07    2014-06-12     Kailahun
# 9   213  8  F   confirmed 2014-06-24    2014-06-29     Kenema
# 10   37 25  F   confirmed 2014-05-29    2014-06-03     Kailahun
# 11  105 30  F   confirmed 2014-06-10    2014-06-15     Kailahun
# 12  217 45  F   confirmed 2014-06-24    2014-07-02     Kailahun
# 13  165 17  M   confirmed 2014-06-15    2014-06-19     Kailahun
# 14   89 30  F   confirmed 2014-06-10    2014-06-15     Kailahun
# ...

# %%
paste("The first patient's ID was", ebola_data[1, 1])
# Out:
# [1] "The first patient's ID was 167"

# %%
paste("The first patient's ID was", head(ebola_data$id, 1))
# Out:
# [1] "The first patient's ID was 167"

# %%
paste("The first patient's ID was", ebola_data$id[1])
# Out:
# [1] "The first patient's ID was 167"

# %%
All the options A, B, and C will successfully achieve this
because they all correctly access the first patient's ID 
from the ebola_data dataframe and concatenate it with the string using the paste() function.

# %%
# question 7
# Look at the following line of code. It produces an error. What is the core reason for this error? 
# (Hint: Think about the data type each function expects and returns).

sqrt(tolower("LUIGI"))

# %%
This is because the sqrt() function is used for numbers 
and the tolower() function is used for characters(strings).

# %%
# question 8
# Using the women dataset and the concepts of function nesting and the paste() function, 
# write one line of code that produces the following output exactly:
# "The average height is 65 inches and the average weight is 136 pounds."
# (You can calculate the average with the mean() function, e.g., mean(women$height)).
# find out about the mean function and $ symbol used in the mean function

# %%
View(women)
# Out:
#    height weight
# 1  58     115
# 2  59     117
# 3  60     120
# 4  61     123
# 5  62     126
# 6  63     129
# 7  64     132
# 8  65     135
# 9  66     139
# 10 67     142
# 11 68     146
# 12 69     150
# 13 70     154
# 14 71     159
# 15 72     164

# %%
paste("The average height is", mean(women$height), "inches and the average
weight is", mean(women$weight), "pounds.")
# Out:
# [1] "The average height is 65 inches and the average\nweight is 136.733333333333 pounds."

# %%
the dollar sign ($) is used to access columns within a dataframe in R.
