# %%
x <- 4
print(x)
# Out:
# [1] 4

# %%
View(x)
# Out:
# [1] 4

# %%
View(women)
# section header
# Out:
#    height weight
# 1  58     115
# 2  59     117
# 3  60     120
# 4  61     123
# 5  62     126
# 6  63     129
# 7  64     132
# 8  65     135
# 9  66     139
# 10 67     142
# 11 68     146
# 12 69     150
# 13 70     154
# 14 71     159
# 15 72     164

# %%
# code 3 - dataframes are objects too
ebola_sierra_leone_data <- read.csv("https://tinyurl.com/ebola-data-sample")
View(ebola_sierra_leone_data)
# Out:
#     id  age sex status    date_of_onset date_of_sample district
# 1   167 55  M   confirmed 2014-06-15    2014-06-21     Kenema
# 2   129 41  M   confirmed 2014-06-13    2014-06-18     Kailahun
# 3   270 12  F   confirmed 2014-06-28    2014-07-03     Kailahun
# 4   187 NA  F   confirmed 2014-06-19    2014-06-24     Kailahun
# 5    85 20  M   confirmed 2014-06-08    2014-06-24     Kailahun
# 6   277 30  F   confirmed 2014-06-29    2014-07-01     Kenema
# 7   263 62  F   confirmed 2014-06-28    2014-07-03     Kenema
# 8    79 45  M   confirmed 2014-06-07    2014-06-12     Kailahun
# 9   213  8  F   confirmed 2014-06-24    2014-06-29     Kenema
# 10   37 25  F   confirmed 2014-05-29    2014-06-03     Kailahun
# 11  105 30  F   confirmed 2014-06-10    2014-06-15     Kailahun
# 12  217 45  F   confirmed 2014-06-24    2014-07-02     Kailahun
# 13  165 17  M   confirmed 2014-06-15    2014-06-19     Kailahun
# 14   89 30  F   confirmed 2014-06-10    2014-06-15     Kailahun
# ...

# %%
# code 4 - renaming dataframe objects
ebola_data <- ebola_sierra_leone_data
View(ebola_data)
# Out:
#     id  age sex status    date_of_onset date_of_sample district
# 1   167 55  M   confirmed 2014-06-15    2014-06-21     Kenema
# 2   129 41  M   confirmed 2014-06-13    2014-06-18     Kailahun
# 3   270 12  F   confirmed 2014-06-28    2014-07-03     Kailahun
# 4   187 NA  F   confirmed 2014-06-19    2014-06-24     Kailahun
# 5    85 20  M   confirmed 2014-06-08    2014-06-24     Kailahun
# 6   277 30  F   confirmed 2014-06-29    2014-07-01     Kenema
# 7   263 62  F   confirmed 2014-06-28    2014-07-03     Kenema
# 8    79 45  M   confirmed 2014-06-07    2014-06-12     Kailahun
# 9   213  8  F   confirmed 2014-06-24    2014-06-29     Kenema
# 10   37 25  F   confirmed 2014-05-29    2014-06-03     Kailahun
# 11  105 30  F   confirmed 2014-06-10    2014-06-15     Kailahun
# 12  217 45  F   confirmed 2014-06-24    2014-07-02     Kailahun
# 13  165 17  M   confirmed 2014-06-15    2014-06-19     Kailahun
# 14   89 30  F   confirmed 2014-06-10    2014-06-15     Kailahun
# ...

# %%
# code 5 - removing original dataframe object
rm(ebola_sierra_leone_data)
View(ebola_data)
# Out:
# Warning message in rm(ebola_sierra_leone_data):
# “object 'ebola_sierra_leone_data' not found”
#     id  age sex status    date_of_onset date_of_sample district
# 1   167 55  M   confirmed 2014-06-15    2014-06-21     Kenema
# 2   129 41  M   confirmed 2014-06-13    2014-06-18     Kailahun
# 3   270 12  F   confirmed 2014-06-28    2014-07-03     Kailahun
# 4   187 NA  F   confirmed 2014-06-19    2014-06-24     Kailahun
# 5    85 20  M   confirmed 2014-06-08    2014-06-24     Kailahun
# 6   277 30  F   confirmed 2014-06-29    2014-07-01     Kenema
# 7   263 62  F   confirmed 2014-06-28    2014-07-03     Kenema
# 8    79 45  M   confirmed 2014-06-07    2014-06-12     Kailahun
# 9   213  8  F   confirmed 2014-06-24    2014-06-29     Kenema
# 10   37 25  F   confirmed 2014-05-29    2014-06-03     Kailahun
# 11  105 30  F   confirmed 2014-06-10    2014-06-15     Kailahun
# 12  217 45  F   confirmed 2014-06-24    2014-07-02     Kailahun
# ...

# %%
# code 6 - error with objects
first_name <- "joanna"
last_name <- "smith"
first_name + last_name

#full_name <- paste(first_name, last_name)
# Out:
# Error in first_name + last_name: non-numeric argument to binary operator
# Traceback:

# %%
# code 7 - functions
sqrt(100)
paste("I am a number:", 42)
plot(women)

# basic function syntax
function_name(argument_1 = val1, argument_2 = val2)

# getting help on functions
# ?name-of-function
?head

# %%
# head function example
# x is the name of your object, the dataset or dataframe we are working with
# by default n is the first 6 rows
head(x = ebola_data, n = 5)

# the order can be changed
head(n = 2, x = ebola_data)
# but in the right order, the arguments can be left out
head(ebola_data, 3)#
#

head(x = ebola_data, n = 10)
# Out:
#   id  age sex status    date_of_onset date_of_sample district
# 1 167 55  M   confirmed 2014-06-15    2014-06-21     Kenema
# 2 129 41  M   confirmed 2014-06-13    2014-06-18     Kailahun
# 3 270 12  F   confirmed 2014-06-28    2014-07-03     Kailahun
# 4 187 NA  F   confirmed 2014-06-19    2014-06-24     Kailahun
# 5  85 20  M   confirmed 2014-06-08    2014-06-24     Kailahun

# %%
# classwork
# In the code lines below, we are attempting to take the top 6 rows of the   dataset
# (which is built into R). Which line is invalid?

head(women)
head(women, 6)
head(x = women, 6)
head(x = women, n = 6)
head(6, women)
# Out:
#   height weight
# 1 58     115
# 2 59     117
# 3 60     120
# 4 61     123
# 5 62     126
# 6 63     129
#   height weight
# 1 58     115
# 2 59     117
# 3 60     120
# 4 61     123
# 5 62     126
# 6 63     129
#   height weight
# 1 58     115
# 2 59     117
# 3 60     120
# 4 61     123
# 5 62     126
# 6 63     129
#   height weight
# 1 58     115
# 2 59     117
# 3 60     120
# 4 61     123
# 5 62     126
# 6 63     129
# Error in checkHT(n, dx <- dim(x)): invalid 'n' - must have length one when dim(x) is NULL, got 2
# Traceback:
#
# 1. head.default(6, women)
# 2. checkHT(n, dx <- dim(x))
# 3. stop(msg, domain = NA)
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "invalid 'n' - must have length one when dim(x) is NULL, got 2",
# ...

# %%
# the paste function can take any number of arguments
# like python print 

# function nesting
# passing the value of an object to another object
paste("my name is ", toupper("luigi"))
# Out:
# [1] "my name is  LUIGI"

# %%
# question
# The code chunks below are all examples of function nesting. One of the lines has an error.
# Which line is it, and what is the error?

sqrt(head(women))
paste(sqrt(9), "plus 1 is", sqrt(16))
sqrt(tolower("LUIGI"))
